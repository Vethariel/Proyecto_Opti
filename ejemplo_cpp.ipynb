// %% [markdown]
// # Notebook C++ con xeus-cling
//
// Este notebook usa el kernel **C++17** (interactivo con [Cling](https://github.com/root-project/cling)).
//
// ## Cómo ejecutarlo
//
// ```bash
// ./iniciar_jupyter.sh
// ```
//
// En JupyterLab, selecciona el kernel **C++17** (o C++14 / C++11).

// %%
#include <iostream>

std::cout << "Hola desde C++ en Jupyter!" << std::endl;
// Out:
// Hola desde C++ en Jupyter!

// %%
// Variables y expresiones (el resultado de la última línea se muestra)
int a = 21;
int b = 2;
a * b
// Out:
// 42

// %%
// Funciones y bucles
#include <vector>
#include <numeric>

std::vector<int> nums{1, 2, 3, 4, 5};
std::accumulate(nums.begin(), nums.end(), 0)
// Out:
// 15

// %%
// Cargar librerías externas (ejemplo con rutas del sistema)
// #pragma cling add_library_path("/usr/lib64")
// #pragma cling load("libm.so")

#include <cmath>
std::sin(M_PI / 2)
// Out:
// 1.0000000
